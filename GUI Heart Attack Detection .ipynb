# %%
import sys
from PyQt5.QtWidgets import QWidget, QLabel, QPushButton, QLineEdit, QVBoxLayout, QHBoxLayout, QApplication, QMessageBox
from PyQt5.QtGui import QDoubleValidator, QFont
from PyQt5.QtWidgets import QMainWindow, QApplication, QLabel
from PyQt5.QtGui import QPixmap
from PyQt5.QtCore import Qt, QLine

import heartattackdetection

class heartattack(QWidget):
    
    def __init__(self) -> None :
        super(heartattack, self).__init__()
        self.setStyleSheet("background-color: #991a1a")
        self.sub_head = QLabel("WOXSEN UNIVERSITY - APPSTEK CORP \nPatient Details")
        self.sub_head.setFont(QFont("Times",28, weight=QFont.Bold))
        self.l0 = QLineEdit()
        self.l1 = QLineEdit()
        self.l2 = QLineEdit()
        self.l3 = QLineEdit()
        self.l4 = QLineEdit()
        self.l5 = QLineEdit()
        self.l6 = QLineEdit()
        self.l7 = QLineEdit()
        self.l8 = QLineEdit()
        self.l9 = QLineEdit()
        self.l10 = QLineEdit()
        self.l11 = QLineEdit()
        self.l12 = QLineEdit()
        self.l13 = QLineEdit()
        self.t0 = QLabel("Patient's Name:")
        self.t1 = QLabel("Patient Age:")
        self.t2 = QLabel("Patient Sex:")
        self.t3 = QLabel("Chest Pain:")
        self.t4 = QLabel("Resting Blood Pressure:")
        self.t5 = QLabel("Cholesterol:")
        self.t6 = QLabel("Fasting Blood Sugar:")
        self.t7= QLabel("Resting ECG:")
        self.t8 = QLabel("Maximum Heart Rate:")
        self.t9 = QLabel("Excersise Induced Angina:")
        self.t10 = QLabel("Old Peak:")
        self.t11 = QLabel("Slope:")
        self.t12 = QLabel("Number of Major Vessels:")
        self.t13= QLabel("Thalium Stress Results:")
        self.r0 = QLabel("(Enter Name Here)")
        self.r1 = QLabel("(Age)")
        self.r2 = QLabel("(Female=0, Male=1)")
        self.r3 = QLabel("(Typical Angina=0, Atypical Angina=1,\nNon-Anginal Pain=2, Asymptomatic=3)")
        self.r4 = QLabel("(mm Hg)")
        self.r5 = QLabel("(mg/dl)")
        self.r6 = QLabel("(> 120 mg/dl = 0, '>126' mg/dL = 1)")
        self.r7 = QLabel("(Nothing = 0, ST-T Wave Abnormality = 1, \nPossible Left Ventricular Hypertroph = 2)")
        self.r8 = QLabel("(BPM)")
        self.r9 = QLabel("(Exercise Induced Angina if Yes = 1, No = 0)")
        self.r10 = QLabel("(ST Depression)")
        self.r11 = QLabel("(Upsloping = 0, Flat Sloping = 1, Down Sloping = 2)")
        self.r12 = QLabel("(Number of Major Vessels 0-3)")
        self.r13 = QLabel("(Normal = 1, Fixed Defect = 2, Reversible Defect = 3)")
        self.h0 = QHBoxLayout()
        self.h1 = QHBoxLayout()
        self.h2 = QHBoxLayout()
        self.h3 = QHBoxLayout()
        self.h4 = QHBoxLayout()
        self.h5 = QHBoxLayout()
        self.h6 = QHBoxLayout()
        self.h7 = QHBoxLayout()
        self.h8 = QHBoxLayout()
        self.h9 = QHBoxLayout()
        self.h10 = QHBoxLayout()
        self.h11 = QHBoxLayout()
        self.h12 = QHBoxLayout()
        self.h13 = QHBoxLayout()
        self.h14 = QHBoxLayout()
        self.h15 = QHBoxLayout()
        self.clbtn = QPushButton("CLEAR")
        self.clbtn.setFixedWidth(120)
        self.submit = QPushButton("PREDICT")
        self.submit.setFixedWidth(120)
        self.v1_box = QVBoxLayout()
        self.v2_box = QVBoxLayout()
        self.final_hbox = QHBoxLayout()
        self.initui()
        
    def initui(self) -> None:
        """ The gui is created and widgets elements are set here """
        self.v1_box.addWidget(self.sub_head)
        self.v1_box.addSpacing(10)
        self.v1_box.setSpacing(5)
        self.l1.setValidator(QDoubleValidator())
        self.l2.setValidator(QDoubleValidator())
        self.l3.setValidator(QDoubleValidator())
        self.l4.setValidator(QDoubleValidator())
        self.l5.setValidator(QDoubleValidator())
        self.l5.setValidator(QDoubleValidator())
        self.l6.setValidator(QDoubleValidator())
        self.l7.setValidator(QDoubleValidator())
        self.l8.setValidator(QDoubleValidator())
        self.l9.setValidator(QDoubleValidator())
        self.l10.setValidator(QDoubleValidator())
        self.l11.setValidator(QDoubleValidator())
        self.l12.setValidator(QDoubleValidator())
        self.l13.setValidator(QDoubleValidator())
        self.l0.setToolTip("Enter Name Here")
        self.l1.setToolTip("Age")
        self.l2.setToolTip("Female=0, Male=1")
        self.l3.setToolTip("Typical Angina=0, Atypical Angina=1, Non-Anginal pain=2, Asymptomatic=3")
        self.l4.setToolTip("mm Hg")
        self.l5.setToolTip("mg/dl")
        self.l6.setToolTip("> 120 mg/dl = 0, '>126' mg/dL = 1")
        self.l7.setToolTip("Nothing = 0, ST-T Wave Abnormality = 1, Possible Left Ventricular Hypertroph = 2")
        self.l8.setToolTip("BPM")
        self.l9.setToolTip("Exercise Induced Angina if Yes = 1, No = 0")
        self.l10.setToolTip("ST Depression")
        self.l11.setToolTip("Upsloping = 0, Flat Sloping = 1, Down Sloping = 2")
        self.l12.setToolTip("Number of Major Vessels 0-3")
        self.l13.setToolTip("Normal = 1, Fixed Defect = 2, Reversible Defect = 3")
        self.l0.setFixedSize(100,30)
        self.l1.setFixedSize(100,30)
        self.l2.setFixedSize(100,30)
        self.l3.setFixedSize(100,30)
        self.l4.setFixedSize(100,30)
        self.l5.setFixedSize(100,30)
        self.l6.setFixedSize(100,30)
        self.l7.setFixedSize(100,30)
        self.l8.setFixedSize(100,30)
        self.l9.setFixedSize(100,30)
        self.l10.setFixedSize(100,30)
        self.l11.setFixedSize(100,30)
        self.l12.setFixedSize(100,30)
        self.l13.setFixedSize(100,30)
        self.v1_box.addLayout(self.h0)
        self.h0.addWidget(self.t0)
        self.h0.addWidget(self.l0)
        self.h0.addWidget(self.r0)
        self.v1_box.addLayout(self.h1)
        self.h1.addWidget(self.t1)
        self.h1.addWidget(self.l1)
        self.h1.addWidget(self.r1)        
        self.v1_box.addLayout(self.h2)
        self.h2.addWidget(self.t2)
        self.h2.addWidget(self.l2)
        self.h2.addWidget(self.r2)       
        self.v1_box.addLayout(self.h3)
        self.h3.addWidget(self.t3)
        self.h3.addWidget(self.l3)
        self.h3.addWidget(self.r3)       
        self.v1_box.addLayout(self.h4)
        self.h4.addWidget(self.t4)
        self.h4.addWidget(self.l4)
        self.h4.addWidget(self.r4)      
        self.v1_box.addLayout(self.h5)
        self.h5.addWidget(self.t5)
        self.h5.addWidget(self.l5)
        self.h5.addWidget(self.r5)
        self.v1_box.addLayout(self.h6)
        self.h6.addWidget(self.t6)
        self.h6.addWidget(self.l6)
        self.h6.addWidget(self.r6)        
        self.v1_box.addLayout(self.h7)
        self.h7.addWidget(self.t7)
        self.h7.addWidget(self.l7)
        self.h7.addWidget(self.r7)       
        self.v1_box.addLayout(self.h8)
        self.h8.addWidget(self.t8)
        self.h8.addWidget(self.l8)
        self.h8.addWidget(self.r8)       
        self.v1_box.addLayout(self.h9)
        self.h9.addWidget(self.t9)
        self.h9.addWidget(self.l9)
        self.h9.addWidget(self.r9)      
        self.v1_box.addLayout(self.h10)
        self.h10.addWidget(self.t10)
        self.h10.addWidget(self.l10)
        self.h10.addWidget(self.r10)
        self.v1_box.addLayout(self.h11)
        self.h11.addWidget(self.t11)
        self.h11.addWidget(self.l11)
        self.h11.addWidget(self.r11)       
        self.v1_box.addLayout(self.h12)
        self.h12.addWidget(self.t12)
        self.h12.addWidget(self.l12)
        self.h12.addWidget(self.r12)      
        self.v1_box.addLayout(self.h13)
        self.h13.addWidget(self.t13)
        self.h13.addWidget(self.l13)
        self.h13.addWidget(self.r13)
        self.v1_box.addLayout(self.h14)
        self.h15 = QHBoxLayout()
        self.submit.clicked.connect(lambda: self.test_input())
        self.submit.setToolTip("Click to check if patient gets heart attack")
        self.clbtn.clicked.connect(lambda: self.clfn())
        self.h15.addWidget(self.submit)
        self.h15.addWidget(self.clbtn)
        self.v1_box.addLayout(self.h15)
        self.report_ui()
        self.final_hbox.addLayout(self.v1_box)
        self.final_hbox.addSpacing(40)
        self.final_hbox.addLayout(self.v2_box)
        self.setLayout(self.final_hbox)
    def report_ui(self):
        self.v2_box.setSpacing(6)
        self.report_subhead = QLabel("About")
        self.report_subhead.setAlignment(Qt.AlignCenter)
        self.report_subhead.setFont(QFont("Times",26, weight=QFont.Bold))
        self.v2_box.addWidget(self.report_subhead)
        self.details = QLabel("This Model uses Support Vector Machine Classifier.\nAccuracy of Model: 83%\n")
        self.details.setFont(QFont("Arial",26, weight=QFont.Bold))
        self.details.setAlignment(Qt.AlignLeft)
        self.details.setWordWrap(True)
        self.model_details = QLabel("Fill Details and Press Predict to see Details.")
        self.model_details.setWordWrap(True)
        self.v2_box.addWidget(self.details)
        self.results = QLabel(" ")
        self.results.setWordWrap(True)
        self.v2_box.addWidget(self.results)
        self.v2_box.addWidget(self.model_details) 
    def clfn(self):
        """ clear all the text fields via clear button"""
        self.l0.clear()
        self.l1.clear()
        self.l2.clear()
        self.l3.clear()
        self.l3.clear()
        self.l4.clear()
        self.l5.clear()
        self.l6.clear()
        self.l7.clear()
        self.l8.clear()
        self.l9.clear()
        self.l10.clear()
        self.l11.clear()
        self.l12.clear()
        self.l13.clear()
        self.report_subhead.setText("About")
        self.model_details.setText("Fill Details and Press Submit to see Details.")
        self.results.setText(" ")
        self.details.setText("This Model uses Support Vector Machine Classifier.\nAccuracy of Model: 83%")
    def test_input(self) -> None:
        """ Test for Heart Disease"""
        my_dict = {"age":float(self.l1.text()),"sex":float(self.l2.text()),
                   "cp":float(self.l3.text()),"trestbps":float(self.l4.text()),
                   "chol":float(self.l5.text()),"fbs":float(self.l6.text()),
                   "restecg":float(self.l7.text()),"thalach":float(self.l8.text()),
                   "exang":float(self.l9.text()),"oldpeak":float(self.l10.text()),
                   "slope":float(self.l11.text()),"ca":float(self.l12.text()),
                   "thal":float(self.l13.text())}
        output = heartattackdetection.check_input(my_dict)
        self.report_subhead.setText("Reports")
        self.model_details.setText("This model uses Support Vector Machine classifier.\nAccuracy of model: 83%\nWe have used heart disease dataset.")
        self.details.setText("Patient's name: {}\nPatient's Age: {} \nPatient's Sex: {}\nChest Pain Type: {}\nResting Blood Pressure: {}\nCholestoral: {}\nFasting Blood Sugar: {}\nResting ECG: {}\nMaximum Heart Rate:  {}".format(self.l0.text(), self.l1.text(), self.l2.text(), self.l3.text(),self.l4.text(),self.l5.text(),self.l6.text(), self.l7.text(), self.l8.text(), self.l9.text(),self.l10.text(),self.l11.text(), self.l12.text(),self.l13.text()))
        
        if output==1:
            self.results.setText("Diagnosis suggests that Patient might Suffer from Heart Attack.")
        elif output==0.5:
            self.results.setText("Our Diagnosis suggests Patient Doesnot Suffer from Heart Attack.")
        else:
            self.results.setText("Our Diagnosis suggests Patient Doesnot suffer from Heart Attack.")
        self.results.setFont(QFont("Arial",30, weight=QFont.Bold))
    def mwindow(self) -> None:
        """ window features are set here and application is loaded into display"""
        self.setFixedSize(1300, 700)
        self.setWindowTitle("Heart Attack  Detection")
        self.clbtn.setStyleSheet("background-color: #002c61")
        self.submit.setStyleSheet("background-color: #006106")
        self.show()
if __name__=="__main__":
    app = QApplication(sys.argv)
    a_window = heartattack()
    a_window.mwindow()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Users/bhanukiran/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
